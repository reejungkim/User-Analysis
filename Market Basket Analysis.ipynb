# %% [markdown]
# ![market%20basket%20analysis.jpg](attachment:market%20basket%20analysis.jpg)

# %%
import pandas as pd
import numpy as np

# %%
#!conda install mlxtend --channel conda-forge
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.loc[pd.isnull(df.Description)]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
df['Description'] = df['Description'].str.strip()

# %%
df.InvoiceNo = df.InvoiceNo.astype(str)
df.Description = df.Description.astype(str)

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
np.sort( df.Description.unique() )
# Out:
# array(['*Boombox Ipod Classic', '*USB Office Mirror Ball',
#        '10 COLOUR SPACEBOY PEN', ..., 'wrongly sold (22719) barcode',
#        'wrongly sold as sets', 'wrongly sold sets'], dtype=object)

# %% [markdown]
# ## remove items to exclude

# %%
np.sort( df.InvoiceNo.unique() )
# Out:
# array(['536365', '536366', '536367', ..., 'C581499', 'C581568', 'C581569'],
#       dtype=object)

# %% [markdown]
# df.loc[df.InvoiceNo.str.contains('C')]

# %%
df = df[~df.InvoiceNo.str.contains('C')]

# %% [markdown]
# df.loc[df.Description.str.contains("wrong")]

# %%
df = df[~df.Description.str.contains('wrong')]

# %% [markdown]
# ## get basket of each invoice

# %%
df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         NaN                      NaN
# 536366                         NaN                      NaN
# 536367                         NaN                      NaN
# 536368                         NaN                      NaN
# 536369                         NaN                      NaN
# ...                            ...                      ...
# 581586                         NaN                      NaN
# 581587                         NaN                      NaN
# A563185                        NaN                      NaN
# A563186                        NaN                      NaN
# A563187                        NaN                      NaN
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          NaN                         NaN
# 536366                          NaN                         NaN
# ...

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))


basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %% [markdown]
# ## return 0 when item was not purchase and 1 when item was purchased

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
#basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# ...

# %% [markdown]
# ## find out which items are frequently purchased together using `apriori` function
#
# The `apriori` function requires us to provide a minimum level of ‘support’. Support is defined as the percentage of time that an itemset appears in the dataset. If you set support = 50%, you’ll only get itemsets that appear 50% of the time. Setting the support level to high could lead to very few (or no) results and setting it too low could require an enormous amount of memory to process the data.

# %%
frequent_itemsets = apriori(basket_sets, 
                            min_support=0.07, 
                            use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4   0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# ..       ...                                                ...
# 85  0.084184  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 86  0.084184  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 87  0.102041  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 88  0.099490  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 89  0.081633  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Application of association rules
#
# metric = 'lift', 'confidence'
#
# minimum threshold (`min_threshold`) for confidence level.
#
# For example, if you set `min_threshold` to 1, you will only see rules with 100% confidence.

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=.05)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 2  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 3    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 4                     (POSTAGE)  (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.102041            0.096939  0.073980    0.725000  7.478947
# 1            0.096939            0.102041  0.073980    0.763158  7.478947
# 2            0.096939            0.094388  0.079082    0.815789  8.642959
# 3            0.094388            0.096939  0.079082    0.837838  8.642959
# 4            0.765306            0.096939  0.084184    0.110000  1.134737
#
#    leverage  conviction
# 0  0.064088    3.283859
# 1  0.064088    3.791383
# 2  0.069932    4.916181
# 3  0.069932    5.568878
# ...

# %% [markdown]
# ## cross-sell recommendation
# If you look in the `antecedents` column and the `consequents` column, you’ll see names of products. Each rule tells us that the `antecedents` is sold along with the `consequents`. You can use this information to build a cross-sell recommendation system that promotes these products with each other on your website (or in person when doing in-person sales).

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                            antecedents  \
# 2                         (ALARM CLOCK BAKELIKE GREEN)
# 3                           (ALARM CLOCK BAKELIKE RED)
# 77                     (SET/6 RED SPOTTY PAPER PLATES)
# 78                     (SET/6 RED SPOTTY PAPER PLATES)
# 79                       (SET/6 RED SPOTTY PAPER CUPS)
# 80               (POSTAGE, ALARM CLOCK BAKELIKE GREEN)
# 81                 (POSTAGE, ALARM CLOCK BAKELIKE RED)
# 117           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 118             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 119                    (SET/6 RED SPOTTY PAPER PLATES)
# 122  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 123  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 124  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 129  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 130  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                                 consequents  antecedent support  \
# ...
